# %% [markdown]
# # Equities minus Bonds vs. World GDP

# %% [markdown]
# ![](source-GEGB-vs-GDP.png)

# %% [markdown]
# ### Source
#
# Coursera, Investment Management Specialization
#
# Financial Markets & the Economy - The Link Between Equity Markets and The Growth-Inflation Mix
#
# Produced by Universite de Geneve
#
# Lecturer: Dr. Michel Girardin

# %% [markdown]
# ### Alternate Sources of Data
#
# As the data used in the original lecture slides is unavailable, alternate data that is judged to be equivalent is used.
#
# For Global Equities, Vanguard Global Equity Inv (VHGEX), source:
# https://uk.finance.yahoo.com/quote/VHGEX/history?p=VHGEX
#
#
#
# For Global Bonds, Vanguard Total Bond Market Index Inv (VBMFX), source:
# https://uk.finance.yahoo.com/quote/VBMFX?p=VBMFX
#
#
#
# For Global GDP, OECD, source:
# https://data.oecd.org/gdp/quarterly-gdp.htm, Extraction settings:
#     * Perspectives: [Total], [Percentage change, same period previous year]
#     * Countries: [OECD - Total]
#     * Time: [Quarterly]

# %%
import pandas as pd
import plotly.graph_objects as go
# %matplotlib inline

# %% [markdown]
# ### Load Data
#
# #### Global Equities

# %%
VHGEX_equities_df = pd.read_csv("VHGEX_OHLCV_YahooFinance_20210305_19950901.csv")
VHGEX_equities_df.set_index("Date",inplace=True)
VHGEX_equities_df.index = pd.to_datetime(VHGEX_equities_df.index)
VHGEX_equities_df_close = VHGEX_equities_df['Adj Close']
VHGEX_equities_df_close.head()
# Out:
# Date
# 1995-09-01    6.577370
# 1995-09-05    6.603215
# 1995-09-06    6.629058
# 1995-09-07    6.641980
# 1995-09-08    6.654903
# Name: Adj Close, dtype: float64

# %%
VHGEX_equities_df_close.resample("BMS")

# %%
VHGEX_equities_df_close.resample("BMS").max()
# Out:
# Date
# 1995-09-01     6.680748
# 1995-10-02     6.648441
# 1995-11-01     6.719513
# 1995-12-01     6.849037
# 1996-01-01     6.985627
#                 ...
# 2020-11-02    37.035633
# 2020-12-01    38.495998
# 2021-01-01    39.700001
# 2021-02-01    41.060001
# 2021-03-01    40.099998
# Freq: BMS, Name: Adj Close, Length: 307, dtype: float64

# %% [markdown]
# #### Global Bonds

# %%
VBMFX_bonds_df = pd.read_csv("VBMFX_OHLCV_YahooFinance_20210305_19861211.csv")
VBMFX_bonds_df.set_index("Date",inplace=True)
VBMFX_bonds_df.index = pd.to_datetime(VBMFX_bonds_df.index)
VBMFX_bonds_df_close = VBMFX_bonds_df['Adj Close']
VBMFX_bonds_df_close.head()
# Out:
# Date
# 1986-12-11    1.733411
# 1986-12-12    1.733411
# 1986-12-15    1.728213
# 1986-12-16    1.733411
# 1986-12-17    1.733411
# Name: Adj Close, dtype: float64

# %% [markdown]
# https://stackoverflow.com/questions/17001389/pandas-resample-documentation

# %% [markdown]
# #### Plot Adj. Closing Prices

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(x=VHGEX_equities_df_close.index,y=VHGEX_equities_df_close,name="equities"))
fig.add_trace(go.Scatter(x=VBMFX_bonds_df_close.index,y=VBMFX_bonds_df_close,name="bonds"))

fig.show()
# Out:
# <div>
#
#
#             <div id="cf491d1d-4758-43f6-b101-d1c81a4683b3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("cf491d1d-4758-43f6-b101-d1c81a4683b3")) {
#                     Plotly.newPlot(
#                         'cf491d1d-4758-43f6-b101-d1c81a4683b3',
#                         [{"name": "equities", "type": "scatter", "x": ["1995-09-01", "1995-09-05", "1995-09-06", "1995-09-07", "1995-09-08", "1995-09-11", "1995-09-12", "1995-09-13", "1995-09-14", "1995-09-15", "1995-09-18", "1995-09-19", "1995-09-20", "1995-09-21", "1995-09-22", "1995-09-25", "1995-09-26", "1995-09-27", "1995-09-28", "1995-09-29", "1995-10-02", "1995-10-03", "1995-10-04", "1995-10-05", "1995-10-06", "1995-10-09", "1995-10-10", "1995-10-11", "1995-10-12", "1995-10-13", "1995-10-16", "1995-10-17", "1995-10-18", "1995-10-19", "1995-10-20", "1995-10-23", "1995-10-24", "1995-10-25", "1995-10-26", "1995-10-27", "1995-10-30", "1995-10-31", "1995-11-01", "1995-11-02", "1995-11-03", "1995-11-06", "1995-11-07", "1995-11-08", "1995-11-09", "1995-11-10", "1995-11-13", "1995-11-14", "1995-11-15", "1995-11-16", "1995-11-17", "1995-11-20", "1995-11-21", "1995-11-22", "1995-11-24", "1995-11-27", "1995-11-28", "1995-11-29", "1995-11-30", "1995-12-01", "1995-12-04", "1995-12-05", "1995-12-06", "1995-12-07", "1995-12-08", "1995-12-11", "1995-12-12", "1995-12-13", "1995-12-14", "1995-12-15", "1995-12-18", "1995-12-19", "1995-12-20", "1995-12-21", "1995-12-22", "1995-12-26", "1995-12-27", "1995-12-28", "1995-12-29", "1996-01-02", "1996-01-03", "1996-01-04", "1996-01-05", "1996-01-08", "1996-01-09", "1996-01-10", "1996-01-11", "1996-01-12", "1996-01-15", "1996-01-16", "1996-01-17", "1996-01-18", "1996-01-19", "1996-01-22", "1996-01-23", "1996-01-24", "1996-01-25", "1996-01-26", "1996-01-29", "1996-01-30", "1996-01-31", "1996-02-01", "1996-02-02", "1996-02-05", "1996-02-06", "1996-02-07", "1996-02-08", "1996-02-09", "1996-02-12", "1996-02-13", "1996-02-14", "1996-02-15", "1996-02-16", "1996-02-20", "1996-02-21", "1996-02-22", "1996-02-23", "1996-02-26", "1996-02-27", "1996-02-28", "1996-02-29", "1996-03-01", "1996-03-04", "1996-03-05", "1996-03-06", "1996-03-07", "1996-03-08", "1996-03-11", "1996-03-12", "1996-03-13", "1996-03-14", "1996-03-15", "1996-03-18", "1996-03-19", "1996-03-20", "1996-03-21", "1996-03-22", "1996-03-25", "1996-03-26", "1996-03-27", "1996-03-28", "1996-03-29", "1996-04-01", "1996-04-02", "1996-04-03", "1996-04-04", "1996-04-08", "1996-04-09", "1996-04-10", "1996-04-11", "1996-04-12", "1996-04-15", "1996-04-16", "1996-04-17", "1996-04-18", "1996-04-19", "1996-04-22", "1996-04-23", "1996-04-24", "1996-04-25", "1996-04-26", "1996-04-29", "1996-04-30", "1996-05-01", "1996-05-02", "1996-05-03", "1996-05-06", "1996-05-07", "1996-05-08", "1996-05-09", "1996-05-10", "1996-05-13", "1996-05-14", "1996-05-15", "1996-05-16", "1996-05-17", "1996-05-20", "1996-05-21", "1996-05-22", "1996-05-23", "1996-05-24", "1996-05-28", "1996-05-29", "1996-05-30", "1996-05-31", "1996-06-03", "1996-06-04", "1996-06-05", "1996-06-06", "1996-06-07", "1996-06-10", "1996-06-11", "1996-06-12", "1996-06-13", "1996-06-14", "1996-06-17", "1996-06-18", "1996-06-19", "1996-06-20", "1996-06-21", "1996-06-24", "1996-06-25", "1996-06-26", "1996-06-27", "1996-06-28", "1996-07-01", "1996-07-02", "1996-07-03", "1996-07-05", "1996-07-08", "1996-07-09", "1996-07-10", "1996-07-11", "1996-07-12", "1996-07-15", "1996-07-16", "1996-07-17", "1996-07-18", "1996-07-19", "1996-07-22", "1996-07-23", "1996-07-24", "1996-07-25", "1996-07-26", "1996-07-29", "1996-07-30", "1996-07-31", "1996-08-01", "1996-08-02", "1996-08-05", "1996-08-06", "1996-08-07", "1996-08-08", "1996-08-09", "1996-08-12", "1996-08-13", "1996-08-14", "1996-08-15", "1996-08-16", "1996-08-19", "1996-08-20", "1996-08-21", "1996-08-22", "1996-08-23", "1996-08-26", "1996-08-27", "1996-08-28", "1996-08-29", "1996-08-30", "1996-09-03", "1996-09-04", "1996-09-05", "1996-09-06", "1996-09-09", "1996-09-10", "1996-09-11", "1996-09-12", "1996-09-13", "1996-09-16", "1996-09-17", "1996-09-18", "1996-09-19", "1996-09-20", "1996-09-23", "1996-09-24", "1996-09-25", "1996-09-26", "1996-09-27", "1996-09-30", "1996-10-01", "1996-10-02", "1996-10-03", "1996-10-04", "1996-10-07", "1996-10-08", "1996-10-09", "1996-10- ...

# %%
VHGEX_equities_df_close_pct_change = VHGEX_equities_df_close.pct_change(periods=365).dropna()
VHGEX_equities_df_close_pct_change
# Out:
# Date
# 1997-02-11    0.190638
# 1997-02-12    0.191957
# 1997-02-13    0.194260
# 1997-02-14    0.194909
# 1997-02-18    0.193577
#                 ...
# 2021-03-01    0.319253
# 2021-03-02    0.315892
# 2021-03-03    0.302535
# 2021-03-04    0.281547
# 2021-03-05    0.300206
# Name: Adj Close, Length: 6056, dtype: float64

# %%
VHGEX_equities_df_close_pct_change.dropna()
# Out:
# Date
# 1997-02-11    0.190638
# 1997-02-12    0.191957
# 1997-02-13    0.194260
# 1997-02-14    0.194909
# 1997-02-18    0.193577
#                 ...
# 2021-03-01    0.319253
# 2021-03-02    0.315892
# 2021-03-03    0.302535
# 2021-03-04    0.281547
# 2021-03-05    0.300206
# Name: Adj Close, Length: 6056, dtype: float64

# %%
VHGEX_equities_df_close.isna().sum()
# Out:
# 0

# %%
#VHGEX_equities_df_close.plot(figsize=(16,4))

# %%
#fig_equities = go.Figure()
#fig_equities.add_trace(go.Scatter(x=VHGEX_equities_df_close.index,y=VHGEX_equities_df_close))
#fig_equities.show()

# %%
VHGEX_equities_df_close_pct_change = VHGEX_equities_df_close.pct_change(periods=365)
VHGEX_equities_df_close_pct_change = VHGEX_equities_df_close.dropna()
VHGEX_equities_df_close_pct_change.head()
# Out:
# Date
# 1995-09-01    6.577370
# 1995-09-05    6.603215
# 1995-09-06    6.629058
# 1995-09-07    6.641980
# 1995-09-08    6.654903
# Name: Adj Close, dtype: float64

# %%
VHGEX_equities_df_close_pct_change.isna().sum()
# Out:
# 0

# %%
#fig_equities = go.Figure()

# %% [markdown]
# ### Global Bond

# %%
VBMFX_bonds_df = pd.read_csv("VBMFX_OHLCV_YahooFinance_20210305_19861211.csv")
VBMFX_bonds_df.set_index("Date",inplace=True)
VBMFX_bonds_df_close = VBMFX_bonds_df['Adj Close']
VBMFX_bonds_df_close.head()

# %%
VBMFX_bonds_df_close.isna().sum()

# %%
VBMFX_bonds_df_close.plot(figsize=(16,4))

# %%
fig_bonds = go.Figure()
fig_bonds.add_trace(go.Scatter(x=VBMFX_bonds_df_close.index,y=VBMFX_bonds_df_close))
fig_bonds.show()

# %% [markdown]
# ### Global Equities Less Global Bond

# %%
test = VHGEX_equities_df_close[:366]

# %%
test

# %%
test.pct_change(periods=365)

# %%
VHGEX_equities_df_close_pct_change = VHGEX_equities_df_close.pct_change(periods=365)
VHGEX_equities_df_close_pct_change = VHGEX_equities_df_close.dropna()
VHGEX_equities_df_close_pct_change.head()

# %%
VHGEX_equities_df_close_pct_change.head(1)

# %%
VHGEX_equities_df_close_pct_change.tail(1)

# %%
len(VHGEX_equities_df_close_pct_change)

# %%
VBMFX_bonds_df_close_pct_change = VBMFX_bonds_df_close.pct_change(periods=365)
VBMFX_bonds_df_close_pct_change = VBMFX_bonds_df_close_pct_change.dropna()
VBMFX_bonds_df_close_pct_change.head()

# %%
VBMFX_bonds_df_close_pct_change.head(1)

# %%
VBMFX_bonds_df_close_pct_change.tail(1)

# %%
len(VBMFX_bonds_df_close_pct_change)

# %%
gegb = pd.concat([VHGEX_equities_df_close_pct_change,VBMFX_bonds_df_close_pct_change],axis=1).dropna()
cols = ["Global Equities","Global Bonds"]
gegb.columns = cols

# %%
gegb.head()

# %%
gegb.tail()

# %%
gegb["GEGB Difference"] = gegb["Global Equities"] - gegb["Global Bonds"]
gegb.head()

# %%
fig2 = go.Figure()

#fig2.add_trace(go.Scatter(x=gegb.index,y=gegb["Global Equities"]))

fig2.add_trace(go.Scatter(x=gegb.index,y=gegb["Global Bonds"]))

#fig2.add_trace(go.Scatter(x=gegb.index,y=gegb["GEGB Difference"]))

# %%
fig2 = go.Figure()

fig2.add_trace(go.Scatter(x=gegb.index,y=gegb["Global Equities"]))

#fig2.add_trace(go.Scatter(x=gegb.index,y=gegb["Global Bonds"]))

#fig2.add_trace(go.Scatter(x=gegb.index,y=gegb["GEGB Difference"]))
